# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import seaborn as sns
import yaml

from loaders import *

# %%
def read_yaml_files_to_dataframe(directory):
    rows_list = []
    for filename in sorted(os.listdir(directory)):
        if filename.endswith(".yaml"):
            file_path = os.path.join(directory, filename)
            file_number = filename.split('.')[0]

            with open(file_path, 'r') as file:
                content = yaml.safe_load(file)

                instance_data = content['problem']['instance']
                bottom_name = content['problem']['shape']['name']

                if len(bottom_name.split('_')) < 3:
                    try:
                        group_name = bottom_name.split('_')[0]
                        layer_type = bottom_name.split('_')[1]
                        resid_block_num = None
                        mamba_block = None
                    except:
                        group_name = None
                        layer_type = bottom_name
                        resid_block_num = None
                        mamba_block = None
                else:
                    group_name = bottom_name.split('_')[0]
                    resid_block_num = int(bottom_name.split('_')[1])
                    mamba_block = bottom_name.split('_')[2]
                    if len(bottom_name.split('_')) == 4:
                        layer_type = bottom_name.split('_')[3]
                    else:
                        layer_type = bottom_name.split('_')[3] + '_' + bottom_name.split('_')[4]

                row_data = {'File Number': file_number, 'Name': bottom_name, 'Group': group_name, 'Residual Block Number': resid_block_num, 'Mamba Block': mamba_block, 'Layer Type': layer_type}
                row_data.update(instance_data)
                rows_list.append(row_data)

    df = pd.DataFrame(rows_list)
    return df


def parse_stats(file_path):
    # Define the keys we want to extract from the stats section
    keys = [
        "GFLOPs (@1GHz)", "Utilization", "Cycles", "Energy", "EDP(J*cycle)", "Area",
        "mac", "psum_spad", "weights_spad", "ifmap_spad", "shared_glb", "DRAM", "Total"
    ]
    values = {}
    
    # Start reading file when "Summary Stats" is found
    all_lines = []
    with open(file_path, 'r') as file:
        record = False
        record_compute = False
        for line in file:
            all_lines.append(line)
            if "Summary Stats" in line:
                record = True
            if "fJ/Compute" in line:
                record_compute = True
            if record:
                if ":" in line:
                    key, value = line.split(':')
                    key = key.strip()
                    value = value.strip().split()[0]  # Split to ignore units and take the first value
                    if key in keys:
                        values[key] = value
                if "Total" in line and line.startswith("    Total"):
                    record = False
            if record_compute:
                if "=" in line:  # Look for lines with '=' which denotes key-value pairs in fJ/Compute section
                    key, value = line.strip().split('=')
                    key = key.strip()
                    value = value.strip().split()[0]  # Strip and split to ignore spaces and units
                    values[key] = value
                if "Total" in line and line.startswith("    Total"):  # Stop recording after Total
                    break
            if "Computes = " in line:
                values["computes"] = line.split(" = ")[1]

    file_str = "".join(all_lines)
    glb_access_str = "=== shared_glb ===\n    Total scalar accesses                   : "
    glb_access_index = file_str.index(glb_access_str) + len(glb_access_str)
    glb_end_index = file_str.index("\n", glb_access_index)
    values["shared_glb_accesses"] = file_str[glb_access_index:glb_end_index]

    dram_access_str = "=== DRAM ===\n    Total scalar accesses                   : "
    dram_access_index = file_str.index(dram_access_str) + len(dram_access_str)
    dram_end_index = file_str.index("\n", dram_access_index)
    values["dram_accesses"] = file_str[dram_access_index:dram_end_index]
    return values

def read_stats_from_directories(base_directory):
    rows_list = []

    # Iterate over subdirectories
    for subdir in sorted(os.listdir(base_directory)):
        dir_path = os.path.join(base_directory, subdir)
        if os.path.isdir(dir_path):
            stats_file = os.path.join(dir_path, 'timeloop-mapper.stats.txt')
            if os.path.exists(stats_file):
                # Parse the stats file
                stats = parse_stats(stats_file)
                # Add the file number (subdirectory name) to the row
                stats['Layer Number'] = subdir
                rows_list.append(stats)

    # Create DataFrame from list of rows
    df = pd.DataFrame(rows_list)
    return df

def create_merged_df(OUTPUT_DIRECTORY, BASE_FOLDER):
    merged_df = pd.merge(read_stats_from_directories(OUTPUT_DIRECTORY), read_yaml_files_to_dataframe(BASE_FOLDER), left_on='Layer Number', right_on='File Number', how='inner')
    merged_df = merged_df.drop(columns=['File Number'])
    return merged_df

def convert_to_floats(merged_df):
    #try converting every column to floats
    for column in merged_df.columns:
        try:
            merged_df[column] = merged_df[column].astype(float)
        except:
            print('failed to convert column to float', column)
            pass

    merged_df['Utilization'] = merged_df['Utilization'].str.rstrip('%').astype('float')
    merged_df.rename(columns={'Utilization': 'Utilization (%)'}, inplace=True)

    return merged_df


merged_df = create_merged_df(
    #"example_designs/example_designs/eyeriss_like/outputs/mamba_1.4b",
    "example_designs/example_designs/eyeriss_like/outputs/gpt2",
    "example_designs/layer_shapes/mamba_1.4b",
)
merged_df = convert_to_floats(merged_df)
# Out:
# failed to convert column to float Utilization
# failed to convert column to float Name
# failed to convert column to float Group
# failed to convert column to float Mamba Block
# failed to convert column to float Layer Type

# %%
merged_df['Layer Type'] = merged_df['Layer Type'].replace(r'^[1-9]$|^[1-3]\d$|^4[0-7]$', 'matmul', regex=True)

cols = ['Energy', 'Cycles', 'computes', 'shared_glb_accesses', 'dram_accesses']
#merged_df.loc[merged_df['Layer Type'] == 'matmul', cols] *= 1024

# %%
merged_df
# Out:
#      GFLOPs (@1GHz)  Utilization (%)        Cycles     Energy  EDP(J*cycle)  \
# 0             23.99             7.14  6.710886e+07    6463.61      434000.0
# 1             15.99             4.76  3.355443e+07    2095.28       70300.0
# 2             15.97             4.76  3.276800e+04       3.06           0.1
# 3             15.97             4.76  1.310720e+05      11.46           1.5
# 4             15.99             4.76  1.342177e+08    7575.74     1020000.0
# ..              ...              ...           ...        ...           ...
# 140           15.97             4.76  3.276800e+04       3.06           0.1
# 141           15.97             4.76  1.310720e+05      11.46           1.5
# 142           15.99             4.76  1.342177e+08    7575.74     1020000.0
# 143           16.00             4.76  1.342177e+08    7931.19     1060000.0
# 144           15.99             4.76  1.646821e+09  142952.91   235000000.0
#
#      Area      computes     mac  psum_spad  weights_spad  ...       M    N  \
# 0     0.0  8.053064e+08  207.69    2767.51       1978.95  ...  8192.0  1.0
# 1     0.0  2.684355e+08  207.69    3004.85       1986.27  ...     1.0  1.0
# 2     0.0  2.621440e+05  207.69    2808.92       2088.73  ...   160.0  1.0
# 3     0.0  1.048576e+06  207.69    2923.31       2088.73  ...  4096.0  1.0
# 4     0.0  1.073742e+09  207.69    2762.24       2000.90  ...    16.0  1.0
# ..    ...           ...     ...        ...           ...  ...     ...  ...
# 140   0.0  2.621440e+05  207.69    2808.92       2088.73  ...   160.0  1.0
# 141   0.0  1.048576e+06  207.69    2923.31       2088.73  ...  4096.0  1.0
# 142   0.0  1.073742e+09  207.69    2762.24       2000.90  ...    16.0  1.0
# 143   0.0  1.073742e+09  207.69    3004.85       1986.27  ...  2048.0  1.0
# 144   0.0  1.317457e+10  207.69    2829.96       2030.18  ...  8192.0  1.0
#
#        P     Q    R       S  Hdilation Hstride Wdilation  Wstride
# 0    1.0   1.0  1.0     1.0        NaN     NaN       NaN      NaN
# 1    1.0  13.0  1.0     4.0        NaN     NaN       NaN      NaN
# 2    1.0   1.0  1.0     1.0        NaN     NaN       NaN      NaN
# 3    1.0   1.0  1.0     1.0        NaN     NaN       NaN      NaN
# 4    1.0   1.0  1.0  4096.0        1.0     1.0       1.0      1.0
# ..   ...   ...  ...     ...        ...     ...       ...      ...
# 140  1.0   1.0  1.0     1.0        NaN     NaN       NaN      NaN
# 141  1.0   1.0  1.0     1.0        NaN     NaN       NaN      NaN
# 142  1.0   1.0  1.0  4096.0        1.0     1.0       1.0      1.0
# 143  1.0   1.0  1.0     1.0        NaN     NaN       NaN      NaN
# 144  1.0   1.0  1.0     1.0        NaN     NaN       NaN      NaN
#
# [145 rows x 34 columns]

# %%
print("Total energy (mJ):", merged_df["Energy"].sum() / 1000)
print(f"Latency (ms): {merged_df['Cycles'].sum() / 1e9 * 1000}")
print("Total computes (B):", merged_df["computes"].sum() / 1e9)
print("GLB accesses (B):", merged_df["shared_glb_accesses"].sum() / 1e9)
print("DRAM accesses (B):", merged_df["dram_accesses"].sum() / 1e9)
# Out:
# Total energy (mJ): 720.8810699999999
# Latency (ms): 10509.123583999999
# Total computes (B): 90.515439616
# GLB accesses (B): 29.598740224
# DRAM accesses (B): 1.667584256

# %% [markdown]
# ## Misc

# %%
show_config('example_designs/layer_shapes/mamba/000.yaml')
# Out:
# problem:
#   instance:
#     C: 1024
#     G: 1
#     M: 4096
#     N: 1
#     P: 1
#     Q: 1
#     R: 1
#     S: 1
#   shape:
#     coefficients:
#     - default: 1024
#       name: Cgroup
#     - default: 4096
#       name: Mgroup
#     - default: 1
#       name: Hstride
#     - default: 1
#       name: Wstride
#     data_spaces:
#     - name: Weights
#       projection:
#       - - - G
#       - - - C
#       - - - M
#       - - - R
#       - - - S
#     - name: Inputs
#       projection:
#       - - - N
#       - - - G
#           - Cgroup
#         - - C
#       - - - R
#         - - P
#           - Hstride
#       - - - S
#         - - Q
#           - Wstride
#     - name: Outputs
#       projection:
#       - - - N
#       - - - G
#           - Mgroup
#         - - M
#       - - - P
#       - - - Q
#       read_write: true
#     dimensions:
#     - G
#     - C
#     - M
#     - R
#     - S
#     - N
#     - P
#     - Q
#     name: layers_0_mixer_in_proj

# %%
show_config('example_designs/example_designs/eyeriss_like/arch.yaml')
# Out:
# architecture:
#   # ============================================================
#   # Architecture Description
#   # ============================================================
#   version: 0.4
#   nodes: # Top-level is hierarchical
#   - !Container # Top-level system
#     name: system
#
#   - !Component # DRAM main memory
#     name: DRAM
#     class: DRAM
#     attributes:
#       type: "LPDDR4"
#       width: 64
#       datawidth: 8
#
#   - !Container # Eyeriss accelerator
#     name: eyeriss
#     attributes:
#       technology: "32nm"
#
#   - !Component # Global buffer for inputs & outputs
#     name: shared_glb
#     class: smartbuffer_SRAM
#     attributes:
#       depth: 16384
#       width: 64
#       n_banks: 32
#       datawidth: 8
#       read_bandwidth: 16
#       write_bandwidth: 16
#     constraints:
#       dataspace: {keep: [Inputs, Outputs], bypass: [Weights]}
#
#   - !Container # Each column of PEs produces a different psum row
#     name: PE_column
#     spatial: {meshX: 14}
#     constraints:
#       spatial:
#         permutation: [N, C, P, R, S, Q, M]
#         factors: [N=1, C=1, P=1, R=1, S=1]
#         split: 7
#
#   - !Container # Each PE in the column receives a different filter row
#     name: PE
#     spatial: {meshY: 12}
#     constraints:
#       spatial:
#         split: 4
#         permutation: [N, P, Q, R, S, C, M]
#         factors: [N=1, P=1, Q=1, R=1]
#
#   - !Parallel # Input/Output/Weight scratchpads in parallel
#     nodes:
#     - !Component # Input scratchpad
#       name: ifmap_spad
#       class: smartbuffer_RF
#       attributes:
#         depth: 12
#         width: 16
#         datawidth: 8
#         read_bandwidth: 2
#         write_bandwidth: 2
#       constraints:
#         dataspace: {keep: [Inputs]}
#         temporal:
#           permutation: [N, M, C, P, Q, R, S]
#           factors: [N=1, M=1, C=1, P=1, Q=1, R=1, S=1]
#
#     - !Component # Weight scratchpad
#       name: weights_spad
#       class: smartbuffer_RF
#       attributes:
#         depth: 192
#         width: 16
#         datawidth: 8
#         read_bandwidth: 2
#         write_bandwidth: 2
#       constraints:
#         dataspace: {keep: [Weights]}
#         temporal:
#           permutation: [N, M, P, Q, S, C, R]
#           factors: [N=1, M=1, P=1, Q=1, S=1]
#
#     - !Component # Output scratchpad
#       name: psum_spad
#       class: smartbuffer_RF
#       attributes:
#         depth: 16
#         width: 16
#         update_fifo_depth: 2
#         datawidth: 16
#         read_bandwidth: 2
#         write_bandwidth: 2
#       constraints:
#         dataspace: {keep: [Outputs]}
#         temporal:
#           permutation: [N, C, P, Q, R, S, M]
#           factors: [N=1, C=1, R=1, S=1, P=1, Q=1]
#
#   - !Component # MAC unit
#     name: mac
#     class: intmac
#     attributes:
#       multiplier_width: 8
#       adder_width: 16

# %%
with open("example_designs/example_designs/eyeriss_like/outputs/mamba/000/timeloop-mapper.stats.txt") as f:
    stats_str = f.read()

print(stats_str)
# Out:
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 168 (14*12)
#     Compute energy        : 0.21 pJ
#
#     STATS
#     -----
#     Utilized instances      : 8
#     Computes (total)        : 4194304
#     Cycles                  : 524288
#     Energy (total)          : 871123.39 pJ
#     Area (total)            : 32225.76 um^2
#
# Level 1
# -------
# === psum_spad ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 16
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 168 (14*12)
#         Shared bandwidth                : -
#         Read bandwidth                  : 2.00
#         Write bandwidth                 : 2.00
#         Multiple buffering              : 1.00
#         Effective size                  : 16
#         Min utilization                 : 0.00
#         Vector access energy            : 1.44 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 4450.16 pJ
#         Area                            : 968.43 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for M in [0:16)
#
#     STATS
#     -----
#     Cycles               : 524288
#     Bandwidth throttling : 1.00
#     Outputs:
#         Partition size                           : 512
#         Utilized capacity                        : 16
#         Utilized instances (max)                 : 8
#         Utilized clusters (max)                  : 8
#         Scalar reads (per-instance)              : 523776
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 524288
#         Temporal reductions (per-instance)       : 523776
#         Address generations (per-cluster)        : 524288
#         Energy (per-scalar-access)               : 1.35 pJ
#         Energy (per-instance)                    : 1411414.81 pJ
#         Energy (total)                           : 11291318.49 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 2.00 words/cycle
#         Shared Bandwidth (total)                 : 15.99 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 7.99 words/cycle
#         Write Bandwidth (per-instance)           : 1.00 words/cycle
#         Write Bandwidth (total)                  : 8.00 words/cycle
#
# Level 2
# -------
# === weights_spad ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 384
#         Word bits                       : 8
#         Block size                      : 2
#         Cluster size                    : 1
#         Instances                       : 168 (14*12)
#         Shared bandwidth                : -
#         Read bandwidth                  : 2.00
#         Write bandwidth                 : 2.00
#         Multiple buffering              : 1.00
#         Effective size                  : 384
#         Min utilization                 : 0.00
#         Vector access energy            : 3.94 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 13342.08 pJ
#         Area                            : 11609.35 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 524288
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 524288
#         Utilized capacity                        : 16
#         Utilized instances (max)                 : 8
#         Utilized clusters (max)                  : 8
#         Scalar reads (per-instance)              : 524288
#         Scalar fills (per-instance)              : 524288
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1048576
#         Energy (per-scalar-access)               : 1.92 pJ
#         Energy (per-instance)                    : 2014290.90 pJ
#         Energy (total)                           : 16114327.22 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 2.00 words/cycle
#         Shared Bandwidth (total)                 : 16.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 8.00 words/cycle
#         Write Bandwidth (per-instance)           : 1.00 words/cycle
#         Write Bandwidth (total)                  : 8.00 words/cycle
#
# Level 3
# -------
# === ifmap_spad ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 24
#         Word bits                       : 8
#         Block size                      : 2
#         Cluster size                    : 1
#         Instances                       : 168 (14*12)
#         Shared bandwidth                : -
#         Read bandwidth                  : 2.00
#         Write bandwidth                 : 2.00
#         Multiple buffering              : 1.00
#         Effective size                  : 24
#         Min utilization                 : 0.00
#         Vector access energy            : 1.44 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 4450.16 pJ
#         Area                            : 726.32 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 524288
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 1024
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 8
#         Utilized clusters (max)                  : 8
#         Scalar reads (per-instance)              : 524288
#         Scalar fills (per-instance)              : 32768
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 557056
#         Energy (per-scalar-access)               : 0.72 pJ
#         Energy (per-instance)                    : 398436.81 pJ
#         Energy (total)                           : 3187494.49 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 1.06 words/cycle
#         Shared Bandwidth (total)                 : 8.50 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 8.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.06 words/cycle
#         Write Bandwidth (total)                  : 0.50 words/cycle
#
# Level 6
# -------
# === shared_glb ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 131072
#         Word bits                       : 8
#         Block size                      : 8
#         Cluster size                    : 1
#         Instances                       : 1 (1*1)
#         Shared bandwidth                : -
#         Read bandwidth                  : 16.00
#         Write bandwidth                 : 16.00
#         Multiple buffering              : 1.00
#         Effective size                  : 131072
#         Min utilization                 : 0.00
#         Vector access energy            : 18.18 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.01 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 2963.28 pJ
#         Area                            : 217363.38 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for C in [0:1024)
#
#     STATS
#     -----
#     Cycles               : 524288
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 1024
#         Utilized capacity                        : 1024
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 32768
#         Scalar fills (per-instance)              : 1024
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 33792
#         Energy (per-scalar-access)               : 2.26 pJ
#         Energy (per-instance)                    : 76290.62 pJ
#         Energy (total)                           : 76290.62 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.06 words/cycle
#         Shared Bandwidth (total)                 : 0.06 words/cycle
#         Read Bandwidth (per-instance)            : 0.06 words/cycle
#         Read Bandwidth (total)                   : 0.06 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 4096
#         Utilized capacity                        : 128
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 4096
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 4096
#         Energy (per-scalar-access)               : 1.77 pJ
#         Energy (per-instance)                    : 7238.62 pJ
#         Energy (total)                           : 7238.62 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.01 words/cycle
#         Shared Bandwidth (total)                 : 0.01 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.01 words/cycle
#         Write Bandwidth (total)                  : 0.01 words/cycle
#
# Level 7
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                      : DRAM
#         Size                            : -
#         Word bits                       : 8
#         Block size                      : 8
#         Cluster size                    : 1
#         Instances                       : 1 (1*1)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : -
#         Min utilization                 : 0.00
#         Vector access energy            : 512.00 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 0.00 pJ
#         Area                            : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for M in [0:32)
#
#     STATS
#     -----
#     Cycles               : 524288
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 4194304
#         Utilized capacity                        : 4194304
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 4194304
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 4194304
#         Energy (per-scalar-access)               : 64.00 pJ
#         Energy (per-instance)                    : 268435456.00 pJ
#         Energy (total)                           : 268435456.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 8.00 words/cycle
#         Shared Bandwidth (total)                 : 8.00 words/cycle
#         Read Bandwidth (per-instance)            : 8.00 words/cycle
#         Read Bandwidth (total)                   : 8.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Inputs:
#         Partition size                           : 1024
#         Utilized capacity                        : 1024
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1024
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1024
#         Energy (per-scalar-access)               : 64.00 pJ
#         Energy (per-instance)                    : 65536.00 pJ
#         Energy (total)                           : 65536.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.00 words/cycle
#         Shared Bandwidth (total)                 : 0.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 4096
#         Utilized capacity                        : 4096
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 4096
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 4096
#         Energy (per-scalar-access)               : 64.00 pJ
#         Energy (per-instance)                    : 262144.00 pJ
#         Energy (total)                           : 262144.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.01 words/cycle
#         Shared Bandwidth (total)                 : 0.01 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.01 words/cycle
#         Write Bandwidth (total)                  : 0.01 words/cycle
#
# Networks
# --------
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 4194304
#     Total reduction ops                     : 4190208
#     Total ops                               : 8384512
#     Total memory accesses required          : 4199424
#     Optimal Op per Byte                     : 2.00
#
# === psum_spad ===
#     Total scalar accesses                   : 8384512
#     Op per Byte                             : 0.50
# === weights_spad ===
#     Total scalar accesses                   : 8388608
#     Op per Byte                             : 1.00
# === ifmap_spad ===
#     Total scalar accesses                   : 4456448
#     Op per Byte                             : 1.88
# === inter_PE_spatial ===
# === inter_PE_column_spatial ===
# === shared_glb ===
#     Total scalar accesses                   : 37888
#     Op per Byte                             : 221.30
# === DRAM ===
#     Total scalar accesses                   : 4199424
#     Op per Byte                             : 2.00
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 15.99
# Utilization: 4.76%
# Cycles: 524288
# Energy: 300.34 uJ
# EDP(J*cycle): 1.57e+02
# Area: 0.00 mm^2
#
# Computes = 4194304
# fJ/Compute
#     mac                                           = 207.69
#     psum_spad                                     = 2693.12
#     weights_spad                                  = 3845.14
#     ifmap_spad                                    = 761.02
#     shared_glb                                    = 20.62
#     DRAM                                          = 64078.12
#     Total                                         = 71605.71
